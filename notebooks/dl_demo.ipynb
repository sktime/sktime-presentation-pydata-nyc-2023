# %%
from sktime.datasets import load_airline
from sktime.forecasting.ltsf import LTSFLinearForecaster
import matplotlib.pyplot as plt

y = load_airline()
y
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
#            ...
# 1960-08    606.0
# 1960-09    508.0
# 1960-10    461.0
# 1960-11    390.0
# 1960-12    432.0
# Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64

# %%
model = LTSFLinearForecaster(
    seq_len=10, pred_len=5, num_epochs=16
)
model.fit(y, fh=[1,2,3,4,5])
# Out:
# LTSFLinearForecaster(pred_len=5, seq_len=10)

# %%
y_pred = model.predict()

# %%
ax = y.plot()
y_pred.plot(ax=ax)
# Out:
# <Axes: xlabel='Period'>
